# %% [markdown]
# # [PsychoPy.ioHub Event Monitoring Framework](http://www.isolver-solutions.com/iohubdocs/index.html)
#
# - PsychoPy.ioHub is a Python package providing a cross-platform computer device event monitoring and storage framework. ioHub is free to use and is GPL version 3 licensed.
# - As of June ,2013 ioHub has merged with PsychoPy and is now a _beta_ submobule of PsychoPy.
# - Support for the following operating Systems:
#     - Windows XP SP3, 7, 8
#     - Apple OS X 10.6+
#     - Linux 2.6+
# - Monitoring of events from computer _devices_ such as:
#     - Keyboard
#     - Mouse
#     - Analog to Digital Converter
#     - XInput compatible gamepad
#     - Remote ioHub Server instances
#     - **Eye Trackers, via the ioHub Common Eye Tracking Interface**
#
# ---
#
# # General System Design and Relationship to PsychoPy
#
# - **Insert Diagram Here**
# - Give **brief** text overview
#
# ---
#
# # Useful Links:
#
# ###Installation
#
# Via PsychoPy and the PsychoPy Python Distributions for Windows and OS X.
#
# ###Documentation
#
# PsychoPy Docs
# ioHub Docs
#
# Docs are yet to be merged between Psychopy and ioHub
#
# ###Support
#
# PsychoPy User Group
#
# ### Want to Contibute?
#
# PsychoPy Developer Group
#
# ---
#
# # High Level API Review
#
# ### Starting the ioHub Server Process
#
# TBD
#
# ### Devices
#
# TBC
#
# ### Events
#
# TBC
#
# ### Quick non-eye tracking demo
#
# TBC
#
# ---
#
# # The ioHub Common Eye Tracker Interface
#
# The Common Eye Tracking Interface provides the same user level Python API for all supported eye tracking hardware, meaning the same experiment script can be run with any supported eye tracker and the same data analyses can be performed on any eye tracking data saved via ioHub in the ioDataStore.*
# * _As long as the event type being used for analysis is supported by the different hardware implementations used._
#
# ### The Common Eye Tracking Interface currently supports the following eye tracking systems:
#
# - **LC Technologies** EyeGaze and EyeFollower models.
# - **SensoMotoric Instruments** iViewX models.
# - **SR Research** EyeLink models.
# - **Tobii Technologies** Tobii models.
#
# ### General areas of supported functionality:
#
# - TBC
#
# ### Using ioHub with the PsychoPy Coder and Builder Environments
#
# - We'll get into that after lunch.
#
# ---
